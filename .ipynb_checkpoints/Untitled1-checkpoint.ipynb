# %%
import pandas as pd

# %%
dataset = pd.read_csv('train.csv')
pd.set_option('display.max_columns',100)

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dataset.shape
# Out:
# (1460, 81)

# %%
numeric_data = [features for features in dataset.columns if dataset[features].dtypes != 'O']

# %%
len(numeric_data)
# Out:
# 38

# %%
dataset[numeric_data].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
dataset.drop('Id', axis=1)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
year_data = [feature for feature in numeric_data if 'Year' in feature or 'Yr' in feature]

# %%
year_data
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
features_with_na = [feature for feature in dataset.columns if dataset[feature].isnull().sum() > 0]

# %%
features_with_na
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for i in features_with_na:
    print(i ,dataset[i].isnull().mean())
# Out:
# LotFrontage 0.1773972602739726
# Alley 0.9376712328767123
# MasVnrType 0.005479452054794521
# MasVnrArea 0.005479452054794521
# BsmtQual 0.025342465753424658
# BsmtCond 0.025342465753424658
# BsmtExposure 0.026027397260273973
# BsmtFinType1 0.025342465753424658
# BsmtFinType2 0.026027397260273973
# Electrical 0.0006849315068493151
# FireplaceQu 0.4726027397260274
# GarageType 0.05547945205479452
# GarageYrBlt 0.05547945205479452
# GarageFinish 0.05547945205479452
# GarageQual 0.05547945205479452
# GarageCond 0.05547945205479452
# PoolQC 0.9952054794520548
# Fence 0.8075342465753425
# MiscFeature 0.963013698630137

# %%
dataset.rename(columns={'Alley':'abcdefghijk'})
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street abcdefghijk  \
# 0        1          60       RL         65.0     8450   Pave         NaN
# 1        2          20       RL         80.0     9600   Pave         NaN
# 2        3          60       RL         68.0    11250   Pave         NaN
# 3        4          70       RL         60.0     9550   Pave         NaN
# 4        5          60       RL         84.0    14260   Pave         NaN
# ...    ...         ...      ...          ...      ...    ...         ...
# 1455  1456          60       RL         62.0     7917   Pave         NaN
# 1456  1457          20       RL         85.0    13175   Pave         NaN
# 1457  1458          70       RL         66.0     9042   Pave         NaN
# 1458  1459          20       RL         68.0     9717   Pave         NaN
# 1459  1460          20       RL         75.0     9937   Pave         NaN
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
dataset.replace({'NaN':'Missing'})
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
dataset.loc[1:2, 'Street'] = 'jay Khandelwal'

# %%
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea          Street Alley  \
# 0        1          60       RL         65.0     8450            Pave   NaN
# 1        2          20       RL         80.0     9600  jay Khandelwal   NaN
# 2        3          60       RL         68.0    11250  jay Khandelwal   NaN
# 3        4          70       RL         60.0     9550            Pave   NaN
# 4        5          60       RL         84.0    14260            Pave   NaN
# ...    ...         ...      ...          ...      ...             ...   ...
# 1455  1456          60       RL         62.0     7917            Pave   NaN
# 1456  1457          20       RL         85.0    13175            Pave   NaN
# 1457  1458          70       RL         66.0     9042            Pave   NaN
# 1458  1459          20       RL         68.0     9717            Pave   NaN
# 1459  1460          20       RL         75.0     9937            Pave   NaN
#
# ...

# %%
filt = (dataset['LotConfig'] == 'Inside')

# %%
dataset[filt]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea          Street Alley  \
# 0        1          60       RL         65.0     8450            Pave   NaN
# 2        3          60       RL         68.0    11250  jay Khandelwal   NaN
# 5        6          50       RL         85.0    14115            Pave   NaN
# 6        7          20       RL         75.0    10084            Pave   NaN
# 8        9          50       RM         51.0     6120            Pave   NaN
# ...    ...         ...      ...          ...      ...             ...   ...
# 1455  1456          60       RL         62.0     7917            Pave   NaN
# 1456  1457          20       RL         85.0    13175            Pave   NaN
# 1457  1458          70       RL         66.0     9042            Pave   NaN
# 1458  1459          20       RL         68.0     9717            Pave   NaN
# 1459  1460          20       RL         75.0     9937            Pave   NaN
#
# ...

# %%
dataset['Year Old'] = dataset['YrSold'] - dataset['YearBuilt']

# %%
dataset['Year Old']
# Out:
# 0        5
# 1       31
# 2        7
# 3       91
# 4        8
#         ..
# 1455     8
# 1456    32
# 1457    69
# 1458    60
# 1459    43
# Name: Year Old, Length: 1460, dtype: int64

# %%
filt = (dataset['Year Old'] >10) & (dataset['Year Old']<20)

# %%
dataset[filt]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 36      37          20       RL        112.0    10859   Pave   NaN      Reg
# 64      65          60       RL          NaN     9375   Pave   NaN      Reg
# 72      73          60       RL         74.0    10141   Pave   NaN      IR1
# 84      85          80       RL          NaN     8530   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1322  1323          60       RL        107.0    10186   Pave   NaN      IR1
# 1353  1354          50       RL         56.0    14720   Pave   NaN      IR1
# 1417  1418          60       RL          NaN    16545   Pave   NaN      IR1
# 1426  1427          60       RL         81.0    10944   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
#
# ...

# %%
dataset.replace({'Year Old':'YearOld'})
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea          Street Alley  \
# 0        1          60       RL         65.0     8450            Pave   NaN
# 1        2          20       RL         80.0     9600  jay Khandelwal   NaN
# 2        3          60       RL         68.0    11250  jay Khandelwal   NaN
# 3        4          70       RL         60.0     9550            Pave   NaN
# 4        5          60       RL         84.0    14260            Pave   NaN
# ...    ...         ...      ...          ...      ...             ...   ...
# 1455  1456          60       RL         62.0     7917            Pave   NaN
# 1456  1457          20       RL         85.0    13175            Pave   NaN
# 1457  1458          70       RL         66.0     9042            Pave   NaN
# 1458  1459          20       RL         68.0     9717            Pave   NaN
# 1459  1460          20       RL         75.0     9937            Pave   NaN
#
# ...

# %%
dataset['Street'] = dataset['Street'].map({'jay Khandelwal':'jay'})

# %%
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450    NaN   NaN      Reg
# 1        2          20       RL         80.0     9600    jay   NaN      Reg
# 2        3          60       RL         68.0    11250    jay   NaN      IR1
# 3        4          70       RL         60.0     9550    NaN   NaN      IR1
# 4        5          60       RL         84.0    14260    NaN   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917    NaN   NaN      Reg
# 1456  1457          20       RL         85.0    13175    NaN   NaN      Reg
# 1457  1458          70       RL         66.0     9042    NaN   NaN      Reg
# 1458  1459          20       RL         68.0     9717    NaN   NaN      Reg
# 1459  1460          20       RL         75.0     9937    NaN   NaN      Reg
#
# ...

# %%
dataset['MSSubClass'].nlargest()
# Out:
# 9      190
# 48     190
# 93     190
# 125    190
# 165    190
# Name: MSSubClass, dtype: int64

# %%
dataset.sort_values(by = 'LotArea', ascending=False)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 313    314          20       RL        150.0   215245    NaN   NaN      IR3
# 335    336         190       RL          NaN   164660    NaN   NaN      IR1
# 249    250          50       RL          NaN   159000    NaN   NaN      IR2
# 706    707          20       RL          NaN   115149    NaN   NaN      IR2
# 451    452          20       RL         62.0    70761    NaN   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1038  1039         160       RM         21.0     1533    NaN   NaN      Reg
# 489    490         180       RM         21.0     1526    NaN   NaN      Reg
# 614    615         180       RM         21.0     1491    NaN   NaN      Reg
# 1039  1040         180       RM         21.0     1477    NaN   NaN      Reg
# 956    957         160       RM         24.0     1300    NaN   NaN      Reg
#
# ...

# %%
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450    NaN   NaN      Reg
# 1        2          20       RL         80.0     9600    jay   NaN      Reg
# 2        3          60       RL         68.0    11250    jay   NaN      IR1
# 3        4          70       RL         60.0     9550    NaN   NaN      IR1
# 4        5          60       RL         84.0    14260    NaN   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917    NaN   NaN      Reg
# 1456  1457          20       RL         85.0    13175    NaN   NaN      Reg
# 1457  1458          70       RL         66.0     9042    NaN   NaN      Reg
# 1458  1459          20       RL         68.0     9717    NaN   NaN      Reg
# 1459  1460          20       RL         75.0     9937    NaN   NaN      Reg
#
# ...
